# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
df = pd.read_csv('/Users/maurits/Documents/Ironhack/week_05/gpw5+6/vanguard-ab-test/data/clean/df_process_clients.csv', parse_dates=['date_time'])

# %%
df.head()
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#             date_time Variation  clnt_tenure_yr  clnt_tenure_mnth  clnt_age  \
# 0 2017-04-17 15:27:07      Test             5.0              64.0      79.0
# 1 2017-04-17 15:26:51      Test             5.0              64.0      79.0
# 2 2017-04-17 15:19:22      Test             5.0              64.0      79.0
# 3 2017-04-17 15:19:13      Test             5.0              64.0      79.0
# 4 2017-04-17 15:18:04      Test             5.0              64.0      79.0
#
#   gendr  num_accts        bal  calls_6_mnth  logons_6_mnth  clnt_age_rounded  \
# 0     U        2.0  189023.86           1.0            4.0              79.0
# 1     U        2.0  189023.86           1.0            4.0              79.0
# 2     U        2.0  189023.86           1.0            4.0              79.0
# 3     U        2.0  189023.86           1.0            4.0              79.0
# 4     U        2.0  189023.86           1.0            4.0              79.0
#
#   age_category
# 0      over 70
# 1      over 70
# 2      over 70
# 3      over 70
# 4      over 70

# %%
df.nunique()
# Out:
# client_id            50500
# visitor_id           56011
# visit_id             69205
# process_step             5
# date_time           283344
# Variation                2
# clnt_tenure_yr          53
# clnt_tenure_mnth       469
# clnt_age               158
# gendr                    4
# num_accts                7
# bal                  50312
# calls_6_mnth             7
# logons_6_mnth            7
# clnt_age_rounded        79
# age_category             7
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321309 entries, 0 to 321308
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   client_id         321309 non-null  int64
#  1   visitor_id        321309 non-null  object
#  2   visit_id          321309 non-null  object
#  3   process_step      321309 non-null  object
#  4   date_time         321309 non-null  datetime64[ns]
#  5   Variation         321309 non-null  object
#  6   clnt_tenure_yr    321207 non-null  float64
#  7   clnt_tenure_mnth  321207 non-null  float64
#  8   clnt_age          321195 non-null  float64
#  9   gendr             321207 non-null  object
#  10  num_accts         321207 non-null  float64
#  11  bal               321207 non-null  float64
#  12  calls_6_mnth      321207 non-null  float64
#  13  logons_6_mnth     321207 non-null  float64
#  14  clnt_age_rounded  321195 non-null  float64
#  15  age_category      321195 non-null  object
# dtypes: datetime64[ns](1), float64(8), int64(1), object(6)
# memory usage: 39.2+ MB

# %%
# df_test = df[df['Variation'] == 'Test']
# df_control = df[df['Variation'] == 'Control']

# %% [markdown]
# # IMPORTANT!!!! Even though the formulas say control below, this concerns the whole dataset (both control and test group)!!!

# %%
df_control = df

# %%
# import pandas as pd
# from datetime import datetime
# from collections import defaultdict

# # Assuming the data is already in a DataFrame called 'df'
# # If not, you'd need to load it first, e.g.:
# # df = pd.read_csv('your_data.csv')

# # Convert date_time to datetime
# df['date_time'] = pd.to_datetime(df['date_time'], format='%d/%m/%Y %H:%M')

# # Sort the dataframe by client_id and date_time
# df = df.sort_values(['client_id', 'date_time'])

# def analyze_client(group):
#     steps = group['process_step'].tolist()
#     times = group['date_time'].tolist()
    
#     went_back = False
#     reached_confirm = False
#     total_duration = None
#     step_durations = defaultdict(float)
#     backtrack_durations = defaultdict(float)
    
#     if 'start' in steps and 'confirm' in steps:
#         reached_confirm = True
#         start_time = group[group['process_step'] == 'start']['date_time'].iloc[0]
#         confirm_time = group[group['process_step'] == 'confirm']['date_time'].iloc[-1]
#         total_duration = (confirm_time - start_time).total_seconds() / 60  # in minutes
    
#     max_step = 0
#     current_step = 'start'
#     last_time = times[0]
    
#     for step, time in zip(steps[1:], times[1:]):
#         duration = (time - last_time).total_seconds() / 60  # in minutes
        
#         if step.startswith('step_'):
#             step_num = int(step.split('_')[1])
#             if step_num < max_step:
#                 went_back = True
#                 backtrack_durations[f'backtrack_to_{step}'] += duration
#             else:
#                 max_step = step_num
        
#         step_durations[current_step] += duration
#         current_step = step
#         last_time = time
    
#     result = {
#         'went_back': went_back,
#         'reached_confirm': reached_confirm,
#         'total_duration_minutes': total_duration
#     }
    
#     # Add step durations to result
#     for step, duration in step_durations.items():
#         result[f'{step}_duration'] = duration
    
#     # Add backtrack durations to result
#     for step, duration in backtrack_durations.items():
#         result[step] = duration
    
#     return pd.Series(result)

# # Apply the analysis function to each client group
# result = df.groupby('client_id').apply(analyze_client).reset_index()

# # Display the results
# print(result)

# # Additional analysis
# print("\nSummary statistics:")
# print(result.describe())

# print("\nCount of clients who went back to previous steps:")
# print(result['went_back'].value_counts())

# print("\nAverage duration for clients who reached confirm stage:")
# print(result[result['reached_confirm']]['total_duration_minutes'].mean())

# print("\nAverage duration for each step:")
# step_columns = [col for col in result.columns if col.endswith('_duration')]
# print(result[step_columns].mean())

# print("\nAverage backtrack durations:")
# backtrack_columns = [col for col in result.columns if col.startswith('backtrack_to_')]
# print(result[backtrack_columns].mean())

# %%
import pandas as pd
from datetime import datetime
from collections import defaultdict

# Assuming the data is already in a DataFrame called 'df'
# If not, you'd need to load it first, e.g.:
# df = pd.read_csv('your_data.csv')

# Convert date_time to datetime
df_control['date_time'] = pd.to_datetime(df_control['date_time'], format='%d/%m/%Y %H:%M')

# Sort the dataframe by client_id and date_time
df_control = df_control.sort_values(['client_id', 'date_time'])

def analyze_client(group):
    steps = group['process_step'].tolist()
    times = group['date_time'].tolist()
    
    went_back = False
    reached_confirm = False
    total_duration = None
    step_durations = defaultdict(float)
    backtrack_durations = defaultdict(float)
    
    if 'start' in steps and 'confirm' in steps:
        reached_confirm = True
        start_time = group[group['process_step'] == 'start']['date_time'].iloc[0]
        confirm_time = group[group['process_step'] == 'confirm']['date_time'].iloc[-1]
        total_duration = (confirm_time - start_time).total_seconds() / 60  # in minutes
    
    max_step = 0
    current_step = 'start'
    last_time = times[0]
    
    for step, time in zip(steps[1:], times[1:]):
        duration = (time - last_time).total_seconds() / 60  # in minutes
        
        if step.startswith('step_'):
            step_num = int(step.split('_')[1])
            if step_num < max_step:
                went_back = True
                backtrack_durations[f'backtrack_to_{step}'] += duration
            else:
                max_step = step_num
        
        step_durations[current_step] += duration
        current_step = step
        last_time = time
    
    result = {
        'went_back': went_back,
        'reached_confirm': reached_confirm,
        'total_duration_minutes': total_duration
    }
    
    # Add step durations to result
    for step, duration in step_durations.items():
        result[f'{step}_duration'] = duration
    
    # Add backtrack durations to result
    for step, duration in backtrack_durations.items():
        result[step] = duration
    
    return pd.Series(result)

# Apply the analysis function to each client group
result_control = df_control.groupby('client_id').apply(analyze_client).reset_index()
# Out:
# /var/folders/3v/mdv6bm7j6n99zg9hqgt9n70r0000gn/T/ipykernel_69542/577244629.py:67: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result_control = df_control.groupby('client_id').apply(analyze_client).reset_index()

# %%
import pandas as pd
from datetime import datetime
from collections import defaultdict

# Assuming the data is already in a DataFrame called 'df'
# If not, you'd need to load it first, e.g.:
# df = pd.read_csv('your_data.csv')

# Convert date_time to datetime
df_test['date_time'] = pd.to_datetime(df_test['date_time'], format='%d/%m/%Y %H:%M')

# Sort the dataframe by client_id and date_time
df_test = df_test.sort_values(['client_id', 'date_time'])

def analyze_client(group):
    steps = group['process_step'].tolist()
    times = group['date_time'].tolist()
    
    went_back = False
    reached_confirm = False
    total_duration = None
    step_durations = defaultdict(float)
    backtrack_durations = defaultdict(float)
    
    if 'start' in steps and 'confirm' in steps:
        reached_confirm = True
        start_time = group[group['process_step'] == 'start']['date_time'].iloc[0]
        confirm_time = group[group['process_step'] == 'confirm']['date_time'].iloc[-1]
        total_duration = (confirm_time - start_time).total_seconds() / 60  # in minutes
    
    max_step = 0
    current_step = 'start'
    last_time = times[0]
    
    for step, time in zip(steps[1:], times[1:]):
        duration = (time - last_time).total_seconds() / 60  # in minutes
        
        if step.startswith('step_'):
            step_num = int(step.split('_')[1])
            if step_num < max_step:
                went_back = True
                backtrack_durations[f'backtrack_to_{step}'] += duration
            else:
                max_step = step_num
        
        step_durations[current_step] += duration
        current_step = step
        last_time = time
    
    result = {
        'went_back': went_back,
        'reached_confirm': reached_confirm,
        'total_duration_minutes': total_duration
    }
    
    # Add step durations to result
    for step, duration in step_durations.items():
        result[f'{step}_duration'] = duration
    
    # Add backtrack durations to result
    for step, duration in backtrack_durations.items():
        result[step] = duration
    
    return pd.Series(result)

# Apply the analysis function to each client group
result_test = df_test.groupby('client_id').apply(analyze_client).reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 10
#       3 from collections import defaultdict
#       5 # Assuming the data is already in a DataFrame called 'df'
#       6 # If not, you'd need to load it first, e.g.:
#       7 # df = pd.read_csv('your_data.csv')
#       8
#       9 # Convert date_time to datetime
# ---> 10 df_test['date_time'] = pd.to_datetime(df_test['date_time'], format='%d/%m/%Y %H:%M')
#      12 # Sort the dataframe by client_id and date_time
#      13 df_test = df_test.sort_values(['client_id', 'date_time'])
#
# NameError: name 'df_test' is not defined

# %%
control_all = result_control.rename(columns={0: 'time'})
# test_all = result_test.rename(columns={0: 'time'})

# %%
control_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 340586 entries, 0 to 340585
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   client_id  340586 non-null  int64
#  1   level_1    340586 non-null  object
#  2   time       323816 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 7.8+ MB

# %%
# Mean finish time control group in hours
control_total_duration = control_all[control_all['level_1'] == 'total_duration_minutes']
control_mean = control_total_duration['time'].mean()
control_mean_hours = (control_mean / 60).round(2)
control_mean_hours
# Out:
# 103.65

# %%
# # Mean finish time test group in hours
# test_total_duration = test_renamed[test_renamed['level_1'] == 'total_duration_minutes']
# test_mean = test_total_duration['time'].mean()
# test_mean_hours = (test_mean / 60).round(2)
# test_mean_hours

# %%
# Count clients finished in control group
control_count_finish = control_all[(control_all['level_1'] == 'reached_confirm') & (control_all['time'] == True)].shape[0]
control_count_finish
control_count_notfinish = control_all[(control_all['level_1'] == 'reached_confirm') & (control_all['time'] == False)].shape[0]
control_count_notfinish

percentage_finish = control_count_finish / (control_count_finish + control_count_notfinish)
percentage_finish
# Out:
# 0.667920792079208

# %%
# # Count clients finished in test group
# test_count_finish = test[(test['level_1'] == 'reached_confirm') & (test['time'] == True)].shape[0]
# test_count_finish
# test_count_notfinish = test[(test['level_1'] == 'reached_confirm') & (test['time'] == False)].shape[0]
# test_count_notfinish

# percentage_finish = test_count_finish / (test_count_finish + test_count_notfinish)
# percentage_finish

# %%
# count total of errors in both datasets, which dataset had the most errors?
# count of total flawless successes in both datasets, which dataset had the most flawless onboardings?
# count the average time spent on each step in both datasets

# If there were errors, where did these occur? And for how long? Were the errors more prevalent on one dataset?

# On a demographic basis, which group perform the best? Men vs women, age vs age
# Were there

# %%
# categories
control_all_went_back = control_all[control_all['level_1'] == 'went_back'] #boolean
control_all_reached_confirm = control_all[control_all['level_1'] == 'reached_confirm'] #boolean
control_all_total_duration_minutes = control_all[control_all['level_1'] == 'total_duration_minutes'] #time
control_all_start_duration = control_all[control_all['level_1'] == 'start_duration'] #time
control_all_step_1_duration = control_all[control_all['level_1'] == 'step_1_duration'] #time
control_all_step_2_duration = control_all[control_all['level_1'] == 'step_2_duration'] #time
control_all_step_3_duration = control_all[control_all['level_1'] == 'step_3_duration'] #time
control_all_total_duration_minutes = control_all[control_all['level_1'] == 'total_duration_minutes'] #time
control_all_backtrack_to_start = control_all[control_all['level_1'] == 'backtrack_to_start'] #time
control_all_backtrack_to_step_1 = control_all[control_all['level_1'] == 'backtrack_to_step_1'] #time
control_all_backtrack_to_step_2 = control_all[control_all['level_1'] == 'backtrack_to_step_2'] #time
control_all_start_duration['time'].max()
# Out:
# 130171.81666666667

# %%
plt.figure(figsize=(10, 6))  # Optional: Set the figure size for better clarity
sns.histplot(control_all_step_1_duration['time'], bins=50, kde=False, edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#remove outliers

# control_all_total_duration_minutes['time'].min()
# control_start_duration
# control_step_1_duration
# control_step_2_duration
# control_step_3_duration
# control_total_duration_minutes
control_backtrack_to_start
# control_backtrack_to_step_1
# control_backtrack_to_step_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 9
#       1 #remove outliers
#       2
#       3 # control_all_total_duration_minutes['time'].min()
#    (...)
#       7 # control_step_3_duration
#       8 # control_total_duration_minutes
# ----> 9 control_backtrack_to_start
#
# NameError: name 'control_backtrack_to_start' is not defined

# %%
# look at who the outliers were -> to which group did they belong?

# %%
# REMOVING OUTLIERS CONTROL_ALL DF

control_all_went_back = control_all_went_back.rename(columns={'time': 'went_back'})
control_all_reached_confirm = control_all_reached_confirm.rename(columns={'time': 'reached_confirm'})

# control all total duration minutes
Q1_td = control_all_total_duration_minutes['time'].quantile(0.25)
Q3_td = control_all_total_duration_minutes['time'].quantile(0.75)
IQR_td = Q3_td - Q1_td
lower_bound_td = Q1_td - 1.5 * IQR_td
upper_bound_td = Q3_td + 1.5 * IQR_td
#filtered df
control_all_TD = control_all_total_duration_minutes[(control_all_total_duration_minutes['time'] >= lower_bound_td) & (control_all_total_duration_minutes['time'] <= upper_bound_td)]
control_all_TD = control_all_TD.rename(columns={'time': 'TD'})


# control_all_start_duration
Q1_sd = control_all_start_duration['time'].quantile(0.25)
Q3_sd = control_all_start_duration['time'].quantile(0.75)
IQR_sd = Q3_sd - Q1_sd
lower_bound_sd = Q1_sd - 1.5 * IQR_sd
upper_bound_sd = Q3_sd + 1.5 * IQR_sd
#filtered df
control_all_SD = control_all_start_duration[(control_all_start_duration['time'] >= lower_bound_sd) & (control_all_start_duration['time'] <= upper_bound_sd)]
control_all_SD = control_all_SD.rename(columns={'time': 'SD'})

# control_step_1_duration
Q1_s1 = control_all_step_1_duration['time'].quantile(0.25)
Q3_s1 = control_all_step_1_duration['time'].quantile(0.75)
IQR_s1 = Q3_s1 - Q1_s1
lower_bound_s1 = Q1_s1 - 1.5 * IQR_s1
upper_bound_s1 = Q3_s1 + 1.5 * IQR_s1
#filtered df
control_all_S1 = control_all_step_1_duration[(control_all_step_1_duration['time'] >= lower_bound_s1) & (control_all_step_1_duration['time'] <= upper_bound_s1)]
control_all_S1 = control_all_S1.rename(columns={'time': 'S1'})

# control_step_2_duration
Q1_s2 = control_all_step_2_duration['time'].quantile(0.25)
Q3_s2 = control_all_step_2_duration['time'].quantile(0.75)
IQR_s2 = Q3_s2 - Q1_s2
lower_bound_s2 = Q1_s2 - 1.5 * IQR_s2
upper_bound_s2 = Q3_s2 + 1.5 * IQR_s2
#filtered df
control_all_S2 = control_all_step_2_duration[(control_all_step_2_duration['time'] >= lower_bound_s2) & (control_all_step_2_duration['time'] <= upper_bound_s2)]
control_all_S2 = control_all_S2.rename(columns={'time': 'S2'})

# control_step_3_duration
Q1_s3 = control_all_step_3_duration['time'].quantile(0.25)
Q3_s3 = control_all_step_3_duration['time'].quantile(0.75)
IQR_s3 = Q3_s3 - Q1_s3
lower_bound_s3 = Q1_s3 - 1.5 * IQR_s3
upper_bound_s3 = Q3_s3 + 1.5 * IQR_s3
#filtered df
control_all_S3 = control_all_step_3_duration[(control_all_step_3_duration['time'] >= lower_bound_s3) & (control_all_step_3_duration['time'] <= upper_bound_s3)]
control_all_S3 = control_all_S3.rename(columns={'time': 'S3'})

# control_backtrack_to_start (NO DATA)
Q1_bs = control_all_backtrack_to_start['time'].quantile(0.25)
Q3_bs = control_all_backtrack_to_start['time'].quantile(0.75)
IQR_bs = Q3_bs - Q1_bs
lower_bound_bs = Q1_bs - 1.5 * IQR_bs
upper_bound_bs = Q3_bs + 1.5 * IQR_bs
#filtered df
control_all_BS = control_all_backtrack_to_start[(control_all_backtrack_to_start['time'] >= lower_bound_bs) & (control_all_backtrack_to_start['time'] <= upper_bound_bs)]
control_all_BS = control_all_BS.rename(columns={'time': 'BS'})

# control_backtrack_to_step_1
Q1_bs1 = control_all_backtrack_to_step_1['time'].quantile(0.25)
Q3_bs1 = control_all_backtrack_to_step_1['time'].quantile(0.75)
IQR_bs1 = Q3_bs1 - Q1_bs1
lower_bound_bs1 = Q1_bs1 - 1.5 * IQR_bs1
upper_bound_bs1 = Q3_bs1 + 1.5 * IQR_bs1
#filtered df
control_all_BS1 = control_all_backtrack_to_step_1[(control_all_backtrack_to_step_1['time'] >= lower_bound_bs1) & (control_all_backtrack_to_step_1['time'] <= upper_bound_bs1)]
control_all_BS1 = control_all_BS1.rename(columns={'time': 'BS1'})

# control_all_backtrack_to_step_2
Q1_bs2 = control_all_backtrack_to_step_2['time'].quantile(0.25)
Q3_bs2 = control_all_backtrack_to_step_2['time'].quantile(0.75)
IQR_bs2 = Q3_bs2 - Q1_bs2
lower_bound_bs2 = Q1_bs2 - 1.5 * IQR_bs2
upper_bound_bs2 = Q3_bs2 + 1.5 * IQR_bs2
#filtered df
control_all_BS2 = control_all_backtrack_to_step_2[(control_all_backtrack_to_step_2['time'] >= lower_bound_bs2) & (control_all_backtrack_to_step_2['time'] <= upper_bound_bs2)]
control_all_BS2 = control_all_BS2.rename(columns={'time': 'BS2'})
control_all_BS2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5598 entries, 26 to 340526
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   client_id  5598 non-null   int64
#  1   level_1    5598 non-null   object
#  2   BS2        5598 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 174.9+ KB

# %%
control_all_total_duration_minutes['time']
# Out:
# 2         2.633333
# 9         6.283333
# 16            None
# 20            None
# 29            None
#             ...
# 340560        None
# 340565    1.983333
# 340572        None
# 340576    47668.85
# 340584        None
# Name: time, Length: 50500, dtype: object

# %%
# concatenating via outer join
concatenated_df_all_filtered = pd.concat([control_all_reached_confirm, control_all_went_back, control_all_TD, control_all_SD, control_all_S1, control_all_S2, control_all_S3, control_all_BS, control_all_BS1, control_all_BS2], axis=0, join='outer', ignore_index=True)
concatenated_df_all_filtered
# Out:
#         client_id              level_1 reached_confirm went_back   TD   SD  \
# 0             555      reached_confirm            True       NaN  NaN  NaN
# 1             647      reached_confirm            True       NaN  NaN  NaN
# 2             934      reached_confirm           False       NaN  NaN  NaN
# 3            1028      reached_confirm           False       NaN  NaN  NaN
# 4            1104      reached_confirm           False       NaN  NaN  NaN
# ...           ...                  ...             ...       ...  ...  ...
# 285712    9995295  backtrack_to_step_2             NaN       NaN  NaN  NaN
# 285713    9997391  backtrack_to_step_2             NaN       NaN  NaN  NaN
# 285714    9997470  backtrack_to_step_2             NaN       NaN  NaN  NaN
# 285715    9998156  backtrack_to_step_2             NaN       NaN  NaN  NaN
# 285716    9998346  backtrack_to_step_2             NaN       NaN  NaN  NaN
#
#          S1   S2   S3   BS  BS1       BS2
# 0       NaN  NaN  NaN  NaN  NaN       NaN
# 1       NaN  NaN  NaN  NaN  NaN       NaN
# 2       NaN  NaN  NaN  NaN  NaN       NaN
# 3       NaN  NaN  NaN  NaN  NaN       NaN
# 4       NaN  NaN  NaN  NaN  NaN       NaN
# ...     ...  ...  ...  ...  ...       ...
# 285712  NaN  NaN  NaN  NaN  NaN       0.0
# 285713  NaN  NaN  NaN  NaN  NaN  1.416667
# 285714  NaN  NaN  NaN  NaN  NaN      0.05
# 285715  NaN  NaN  NaN  NaN  NaN  0.033333
# 285716  NaN  NaN  NaN  NaN  NaN  0.266667
#
# [285717 rows x 12 columns]

# %%
sorted_df = concatenated_df_all_filtered.sort_values(by='client_id', ascending=True)
sorted_df.head(30)

#check if we can convert the floats to minutes/seconds
# Out:
#         client_id                 level_1 reached_confirm went_back        TD  \
# 0             555         reached_confirm            True       NaN       NaN
# 101000        555  total_duration_minutes             NaN       NaN  2.633333
# 166198        555         step_1_duration             NaN       NaN       NaN
# 203270        555         step_2_duration             NaN       NaN       NaN
# 50500         555               went_back             NaN     False       NaN
# 239695        555         step_3_duration             NaN       NaN       NaN
# 127305        555          start_duration             NaN       NaN       NaN
# 239696        647         step_3_duration             NaN       NaN       NaN
# 50501         647               went_back             NaN     False       NaN
# 101001        647  total_duration_minutes             NaN       NaN  6.283333
# 1             647         reached_confirm            True       NaN       NaN
# 166199        647         step_1_duration             NaN       NaN       NaN
# 127306        647          start_duration             NaN       NaN       NaN
# 203271        647         step_2_duration             NaN       NaN       NaN
# 127307        934          start_duration             NaN       NaN       NaN
# 50502         934               went_back             NaN     False       NaN
# 2             934         reached_confirm           False       NaN       NaN
# 239697       1028         step_3_duration             NaN       NaN       NaN
# 50503        1028               went_back             NaN      True       NaN
# 271852       1028     backtrack_to_step_1             NaN       NaN       NaN
# 280119       1028     backtrack_to_step_2             NaN       NaN       NaN
# 127308       1028          start_duration             NaN       NaN       NaN
# 166200       1028         step_1_duration             NaN       NaN       NaN
# 3            1028         reached_confirm           False       NaN       NaN
# 4            1104         reached_confirm           False       NaN       NaN
# 50504        1104               went_back             NaN     False       NaN
# 50505        1186               went_back             NaN     False       NaN
# 5            1186         reached_confirm           False       NaN       NaN
# 166201       1186         step_1_duration             NaN       NaN       NaN
# 127309       1195          start_duration             NaN       NaN       NaN
#
#               SD        S1    S2        S3   BS       BS1       BS2
# 0            NaN       NaN   NaN       NaN  NaN       NaN       NaN
# 101000       NaN       NaN   NaN       NaN  NaN       NaN       NaN
# 166198       NaN  0.533333   NaN       NaN  NaN       NaN       NaN
# 203270       NaN       NaN  1.65       NaN  NaN       NaN       NaN
# 50500        NaN       NaN   NaN       NaN  NaN       NaN       NaN
# 239695       NaN       NaN   NaN  0.333333  NaN       NaN       NaN
# 127305  0.116667       NaN   NaN       NaN  NaN       NaN       NaN
# 239696       NaN       NaN   NaN  2.716667  NaN       NaN       NaN
# 50501        NaN       NaN   NaN       NaN  NaN       NaN       NaN
# 101001       NaN       NaN   NaN       NaN  NaN       NaN       NaN
# 1            NaN       NaN   NaN       NaN  NaN       NaN       NaN
# 166199       NaN       0.3   NaN       NaN  NaN       NaN       NaN
# 127306  0.116667       NaN   NaN       NaN  NaN       NaN       NaN
# 203271       NaN       NaN  3.15       NaN  NaN       NaN       NaN
# 127307  2.366667       NaN   NaN       NaN  NaN       NaN       NaN
# 50502        NaN       NaN   NaN       NaN  NaN       NaN       NaN
# 2            NaN       NaN   NaN       NaN  NaN       NaN       NaN
# 239697       NaN       NaN   NaN      1.85  NaN       NaN       NaN
# 50503        NaN       NaN   NaN       NaN  NaN       NaN       NaN
# 271852       NaN       NaN   NaN       NaN  NaN  2.333333       NaN
# 280119       NaN       NaN   NaN       NaN  NaN       NaN  0.033333
# 127308  0.816667       NaN   NaN       NaN  NaN       NaN       NaN
# 166200       NaN  1.566667   NaN       NaN  NaN       NaN       NaN
# 3            NaN       NaN   NaN       NaN  NaN       NaN       NaN
# 4            NaN       NaN   NaN       NaN  NaN       NaN       NaN
# 50504        NaN       NaN   NaN       NaN  NaN       NaN       NaN
# 50505        NaN       NaN   NaN       NaN  NaN       NaN       NaN
# 5            NaN       NaN   NaN       NaN  NaN       NaN       NaN
# 166201       NaN  0.183333   NaN       NaN  NaN       NaN       NaN
# 127309      0.55       NaN   NaN       NaN  NaN       NaN       NaN

# %%
sorted_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 285717 entries, 0 to 100999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   client_id        285717 non-null  int64
#  1   level_1          285717 non-null  object
#  2   reached_confirm  50500 non-null   object
#  3   went_back        50500 non-null   object
#  4   TD               26305 non-null   object
#  5   SD               38893 non-null   object
#  6   S1               37072 non-null   object
#  7   S2               36425 non-null   object
#  8   S3               32157 non-null   object
#  9   BS               0 non-null       object
#  10  BS1              8267 non-null    object
#  11  BS2              5598 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 28.3+ MB

# %%
df.head()
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#             date_time Variation  clnt_tenure_yr  clnt_tenure_mnth  clnt_age  \
# 0 2017-04-17 15:27:07      Test             5.0              64.0      79.0
# 1 2017-04-17 15:26:51      Test             5.0              64.0      79.0
# 2 2017-04-17 15:19:22      Test             5.0              64.0      79.0
# 3 2017-04-17 15:19:13      Test             5.0              64.0      79.0
# 4 2017-04-17 15:18:04      Test             5.0              64.0      79.0
#
#   gendr  num_accts        bal  calls_6_mnth  logons_6_mnth  clnt_age_rounded  \
# 0     U        2.0  189023.86           1.0            4.0              79.0
# 1     U        2.0  189023.86           1.0            4.0              79.0
# 2     U        2.0  189023.86           1.0            4.0              79.0
# 3     U        2.0  189023.86           1.0            4.0              79.0
# 4     U        2.0  189023.86           1.0            4.0              79.0
#
#   age_category
# 0      over 70
# 1      over 70
# 2      over 70
# 3      over 70
# 4      over 70

# %%
selected_columns_df = df[['client_id', 'Variation', 'clnt_tenure_yr', 'clnt_tenure_mnth', 'clnt_age', 'gendr', 'num_accts', 'bal', 'calls_6_mnth', 'logons_6_mnth', 'clnt_age_rounded', 'age_category']]
selected_columns_df
# Out:
#         client_id Variation  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  \
# 0         9988021      Test             5.0              64.0      79.0     U
# 1         9988021      Test             5.0              64.0      79.0     U
# 2         9988021      Test             5.0              64.0      79.0     U
# 3         9988021      Test             5.0              64.0      79.0     U
# 4         9988021      Test             5.0              64.0      79.0     U
# ...           ...       ...             ...               ...       ...   ...
# 321304    6334360      Test             4.0              53.0      66.5     U
# 321305    6334360      Test             4.0              53.0      66.5     U
# 321306    6334360      Test             4.0              53.0      66.5     U
# 321307    6334360      Test             4.0              53.0      66.5     U
# 321308    6334360      Test             4.0              53.0      66.5     U
#
#         num_accts        bal  calls_6_mnth  logons_6_mnth  clnt_age_rounded  \
# 0             2.0  189023.86           1.0            4.0              79.0
# 1             2.0  189023.86           1.0            4.0              79.0
# 2             2.0  189023.86           1.0            4.0              79.0
# 3             2.0  189023.86           1.0            4.0              79.0
# 4             2.0  189023.86           1.0            4.0              79.0
# ...           ...        ...           ...            ...               ...
# 321304        2.0   93103.47           6.0            9.0              66.0
# 321305        2.0   93103.47           6.0            9.0              66.0
# 321306        2.0   93103.47           6.0            9.0              66.0
# 321307        2.0   93103.47           6.0            9.0              66.0
# 321308        2.0   93103.47           6.0            9.0              66.0
#
#        age_category
# 0           over 70
# 1           over 70
# 2           over 70
# 3           over 70
# 4           over 70
# ...             ...
# 321304        60-70
# 321305        60-70
# 321306        60-70
# 321307        60-70
# 321308        60-70
#
# [321309 rows x 12 columns]

# %%
combined = pd.merge(sorted_df, selected_columns_df, on='client_id', how='left')

# %%
combined.head(30)
# Out:
#     client_id                 level_1 reached_confirm went_back        TD  \
# 0         555         reached_confirm            True       NaN       NaN
# 1         555         reached_confirm            True       NaN       NaN
# 2         555         reached_confirm            True       NaN       NaN
# 3         555         reached_confirm            True       NaN       NaN
# 4         555         reached_confirm            True       NaN       NaN
# 5         555  total_duration_minutes             NaN       NaN  2.633333
# 6         555  total_duration_minutes             NaN       NaN  2.633333
# 7         555  total_duration_minutes             NaN       NaN  2.633333
# 8         555  total_duration_minutes             NaN       NaN  2.633333
# 9         555  total_duration_minutes             NaN       NaN  2.633333
# 10        555         step_1_duration             NaN       NaN       NaN
# 11        555         step_1_duration             NaN       NaN       NaN
# 12        555         step_1_duration             NaN       NaN       NaN
# 13        555         step_1_duration             NaN       NaN       NaN
# 14        555         step_1_duration             NaN       NaN       NaN
# 15        555         step_2_duration             NaN       NaN       NaN
# 16        555         step_2_duration             NaN       NaN       NaN
# 17        555         step_2_duration             NaN       NaN       NaN
# 18        555         step_2_duration             NaN       NaN       NaN
# 19        555         step_2_duration             NaN       NaN       NaN
# 20        555               went_back             NaN     False       NaN
# 21        555               went_back             NaN     False       NaN
# 22        555               went_back             NaN     False       NaN
# 23        555               went_back             NaN     False       NaN
# 24        555               went_back             NaN     False       NaN
# 25        555         step_3_duration             NaN       NaN       NaN
# 26        555         step_3_duration             NaN       NaN       NaN
# 27        555         step_3_duration             NaN       NaN       NaN
# 28        555         step_3_duration             NaN       NaN       NaN
# 29        555         step_3_duration             NaN       NaN       NaN
#
#      SD        S1    S2        S3   BS  ... clnt_tenure_yr clnt_tenure_mnth  \
# 0   NaN       NaN   NaN       NaN  NaN  ...            3.0             46.0
# 1   NaN       NaN   NaN       NaN  NaN  ...            3.0             46.0
# 2   NaN       NaN   NaN       NaN  NaN  ...            3.0             46.0
# 3   NaN       NaN   NaN       NaN  NaN  ...            3.0             46.0
# 4   NaN       NaN   NaN       NaN  NaN  ...            3.0             46.0
# 5   NaN       NaN   NaN       NaN  NaN  ...            3.0             46.0
# 6   NaN       NaN   NaN       NaN  NaN  ...            3.0             46.0
# 7   NaN       NaN   NaN       NaN  NaN  ...            3.0             46.0
# 8   NaN       NaN   NaN       NaN  NaN  ...            3.0             46.0
# 9   NaN       NaN   NaN       NaN  NaN  ...            3.0             46.0
# 10  NaN  0.533333   NaN       NaN  NaN  ...            3.0             46.0
# 11  NaN  0.533333   NaN       NaN  NaN  ...            3.0             46.0
# 12  NaN  0.533333   NaN       NaN  NaN  ...            3.0             46.0
# 13  NaN  0.533333   NaN       NaN  NaN  ...            3.0             46.0
# 14  NaN  0.533333   NaN       NaN  NaN  ...            3.0             46.0
# 15  NaN       NaN  1.65       NaN  NaN  ...            3.0             46.0
# 16  NaN       NaN  1.65       NaN  NaN  ...            3.0             46.0
# 17  NaN       NaN  1.65       NaN  NaN  ...            3.0             46.0
# 18  NaN       NaN  1.65       NaN  NaN  ...            3.0             46.0
# 19  NaN       NaN  1.65       NaN  NaN  ...            3.0             46.0
# 20  NaN       NaN   NaN       NaN  NaN  ...            3.0             46.0
# 21  NaN       NaN   NaN       NaN  NaN  ...            3.0             46.0
# 22  NaN       NaN   NaN       NaN  NaN  ...            3.0             46.0
# 23  NaN       NaN   NaN       NaN  NaN  ...            3.0             46.0
# 24  NaN       NaN   NaN       NaN  NaN  ...            3.0             46.0
# 25  NaN       NaN   NaN  0.333333  NaN  ...            3.0             46.0
# 26  NaN       NaN   NaN  0.333333  NaN  ...            3.0             46.0
# 27  NaN       NaN   NaN  0.333333  NaN  ...            3.0             46.0
# 28  NaN       NaN   NaN  0.333333  NaN  ...            3.0             46.0
# 29  NaN       NaN   NaN  0.333333  NaN  ...            3.0             46.0
#
#    clnt_age  gendr  num_accts       bal calls_6_mnth  logons_6_mnth  \
# 0      29.5      U        2.0  25454.66          2.0            6.0
# 1      29.5      U        2.0  25454.66          2.0            6.0
# 2      29.5      U        2.0  25454.66          2.0            6.0
# 3      29.5      U        2.0  25454.66          2.0            6.0
# 4      29.5      U        2.0  25454.66          2.0            6.0
# 5      29.5      U        2.0  25454.66          2.0            6.0
# 6      29.5      U        2.0  25454.66          2.0            6.0
# 7      29.5      U        2.0  25454.66          2.0            6.0
# 8      29.5      U        2.0  25454.66          2.0            6.0
# 9      29.5      U        2.0  25454.66          2.0            6.0
# 10     29.5      U        2.0  25454.66          2.0            6.0
# 11     29.5      U        2.0  25454.66          2.0            6.0
# 12     29.5      U        2.0  25454.66          2.0            6.0
# 13     29.5      U        2.0  25454.66          2.0            6.0
# 14     29.5      U        2.0  25454.66          2.0            6.0
# 15     29.5      U        2.0  25454.66          2.0            6.0
# 16     29.5      U        2.0  25454.66          2.0            6.0
# 17     29.5      U        2.0  25454.66          2.0            6.0
# 18     29.5      U        2.0  25454.66          2.0            6.0
# 19     29.5      U        2.0  25454.66          2.0            6.0
# 20     29.5      U        2.0  25454.66          2.0            6.0
# 21     29.5      U        2.0  25454.66          2.0            6.0
# 22     29.5      U        2.0  25454.66          2.0            6.0
# 23     29.5      U        2.0  25454.66          2.0            6.0
# 24     29.5      U        2.0  25454.66          2.0            6.0
# 25     29.5      U        2.0  25454.66          2.0            6.0
# 26     29.5      U        2.0  25454.66          2.0            6.0
# 27     29.5      U        2.0  25454.66          2.0            6.0
# 28     29.5      U        2.0  25454.66          2.0            6.0
# 29     29.5      U        2.0  25454.66          2.0            6.0
#
#     clnt_age_rounded  age_category
# 0               30.0         20-30
# 1               30.0         20-30
# 2               30.0         20-30
# 3               30.0         20-30
# 4               30.0         20-30
# 5               30.0         20-30
# 6               30.0         20-30
# 7               30.0         20-30
# 8               30.0         20-30
# 9               30.0         20-30
# 10              30.0         20-30
# 11              30.0         20-30
# 12              30.0         20-30
# 13              30.0         20-30
# 14              30.0         20-30
# 15              30.0         20-30
# 16              30.0         20-30
# 17              30.0         20-30
# 18              30.0         20-30
# 19              30.0         20-30
# 20              30.0         20-30
# 21              30.0         20-30
# 22              30.0         20-30
# 23              30.0         20-30
# 24              30.0         20-30
# 25              30.0         20-30
# 26              30.0         20-30
# 27              30.0         20-30
# 28              30.0         20-30
# 29              30.0         20-30
#
# [30 rows x 23 columns]

# %%
df_dropped = combined.drop_duplicates()
df_dropped
# Out:
#          client_id                 level_1 reached_confirm went_back  \
# 0              555         reached_confirm            True       NaN
# 5              555  total_duration_minutes             NaN       NaN
# 10             555         step_1_duration             NaN       NaN
# 15             555         step_2_duration             NaN       NaN
# 20             555               went_back             NaN     False
# ...            ...                     ...             ...       ...
# 1919544    9999729               went_back             NaN      True
# 1919555    9999729         reached_confirm            True       NaN
# 1919566    9999832         reached_confirm           False       NaN
# 1919568    9999832          start_duration             NaN       NaN
# 1919570    9999832               went_back             NaN     False
#
#                TD        SD        S1    S2   S3   BS  ... clnt_tenure_yr  \
# 0             NaN       NaN       NaN   NaN  NaN  NaN  ...            3.0
# 5        2.633333       NaN       NaN   NaN  NaN  NaN  ...            3.0
# 10            NaN       NaN  0.533333   NaN  NaN  NaN  ...            3.0
# 15            NaN       NaN       NaN  1.65  NaN  NaN  ...            3.0
# 20            NaN       NaN       NaN   NaN  NaN  NaN  ...            3.0
# ...           ...       ...       ...   ...  ...  ...  ...            ...
# 1919544       NaN       NaN       NaN   NaN  NaN  NaN  ...           10.0
# 1919555       NaN       NaN       NaN   NaN  NaN  NaN  ...           10.0
# 1919566       NaN       NaN       NaN   NaN  NaN  NaN  ...           23.0
# 1919568       NaN  0.133333       NaN   NaN  NaN  NaN  ...           23.0
# 1919570       NaN       NaN       NaN   NaN  NaN  NaN  ...           23.0
#
#         clnt_tenure_mnth clnt_age  gendr  num_accts        bal calls_6_mnth  \
# 0                   46.0     29.5      U        2.0   25454.66          2.0
# 5                   46.0     29.5      U        2.0   25454.66          2.0
# 10                  46.0     29.5      U        2.0   25454.66          2.0
# 15                  46.0     29.5      U        2.0   25454.66          2.0
# 20                  46.0     29.5      U        2.0   25454.66          2.0
# ...                  ...      ...    ...        ...        ...          ...
# 1919544            124.0     31.0      F        3.0  107059.74          6.0
# 1919555            124.0     31.0      F        3.0  107059.74          6.0
# 1919566            281.0     49.0      F        2.0  431887.61          1.0
# 1919568            281.0     49.0      F        2.0  431887.61          1.0
# 1919570            281.0     49.0      F        2.0  431887.61          1.0
#
#          logons_6_mnth  clnt_age_rounded  age_category
# 0                  6.0              30.0         20-30
# 5                  6.0              30.0         20-30
# 10                 6.0              30.0         20-30
# 15                 6.0              30.0         20-30
# 20                 6.0              30.0         20-30
# ...                ...               ...           ...
# 1919544            9.0              31.0         30-40
# 1919555            9.0              31.0         30-40
# 1919566            4.0              49.0         40-50
# 1919568            4.0              49.0         40-50
# 1919570            4.0              49.0         40-50
#
# [285717 rows x 23 columns]

# %%
df_dropped.columns
# Out:
# Index(['client_id', 'level_1', 'reached_confirm', 'went_back', 'TD', 'SD',
#        'S1', 'S2', 'S3', 'BS', 'BS1', 'BS2', 'Variation', 'clnt_tenure_yr',
#        'clnt_tenure_mnth', 'clnt_age', 'gendr', 'num_accts', 'bal',
#        'calls_6_mnth', 'logons_6_mnth', 'clnt_age_rounded', 'age_category'],
#       dtype='object')

# %%
# Test if mean compution works
df_dropped['Variation']==()
# Out:
# 6.251266552619873

# %%
df_reset_drop = df_dropped.reset_index(drop=True)
df_reset_drop
# Out:
#         client_id                 level_1 reached_confirm went_back        TD  \
# 0             555         reached_confirm            True       NaN       NaN
# 1             555  total_duration_minutes             NaN       NaN  2.633333
# 2             555         step_1_duration             NaN       NaN       NaN
# 3             555         step_2_duration             NaN       NaN       NaN
# 4             555               went_back             NaN     False       NaN
# ...           ...                     ...             ...       ...       ...
# 285712    9999729               went_back             NaN      True       NaN
# 285713    9999729         reached_confirm            True       NaN       NaN
# 285714    9999832         reached_confirm           False       NaN       NaN
# 285715    9999832          start_duration             NaN       NaN       NaN
# 285716    9999832               went_back             NaN     False       NaN
#
#               SD        S1    S2   S3   BS  ... clnt_tenure_yr  \
# 0            NaN       NaN   NaN  NaN  NaN  ...            3.0
# 1            NaN       NaN   NaN  NaN  NaN  ...            3.0
# 2            NaN  0.533333   NaN  NaN  NaN  ...            3.0
# 3            NaN       NaN  1.65  NaN  NaN  ...            3.0
# 4            NaN       NaN   NaN  NaN  NaN  ...            3.0
# ...          ...       ...   ...  ...  ...  ...            ...
# 285712       NaN       NaN   NaN  NaN  NaN  ...           10.0
# 285713       NaN       NaN   NaN  NaN  NaN  ...           10.0
# 285714       NaN       NaN   NaN  NaN  NaN  ...           23.0
# 285715  0.133333       NaN   NaN  NaN  NaN  ...           23.0
# 285716       NaN       NaN   NaN  NaN  NaN  ...           23.0
#
#        clnt_tenure_mnth clnt_age  gendr  num_accts        bal calls_6_mnth  \
# 0                  46.0     29.5      U        2.0   25454.66          2.0
# 1                  46.0     29.5      U        2.0   25454.66          2.0
# 2                  46.0     29.5      U        2.0   25454.66          2.0
# 3                  46.0     29.5      U        2.0   25454.66          2.0
# 4                  46.0     29.5      U        2.0   25454.66          2.0
# ...                 ...      ...    ...        ...        ...          ...
# 285712            124.0     31.0      F        3.0  107059.74          6.0
# 285713            124.0     31.0      F        3.0  107059.74          6.0
# 285714            281.0     49.0      F        2.0  431887.61          1.0
# 285715            281.0     49.0      F        2.0  431887.61          1.0
# 285716            281.0     49.0      F        2.0  431887.61          1.0
#
#         logons_6_mnth  clnt_age_rounded  age_category
# 0                 6.0              30.0         20-30
# 1                 6.0              30.0         20-30
# 2                 6.0              30.0         20-30
# 3                 6.0              30.0         20-30
# 4                 6.0              30.0         20-30
# ...               ...               ...           ...
# 285712            9.0              31.0         30-40
# 285713            9.0              31.0         30-40
# 285714            4.0              49.0         40-50
# 285715            4.0              49.0         40-50
# 285716            4.0              49.0         40-50
#
# [285717 rows x 23 columns]

# %%
df_reset_drop.to_csv('dataset_TVC_MS.csv', index=True)

# %%
df_reset_drop
# Out:
#         client_id                 level_1 reached_confirm went_back        TD  \
# 0             555         reached_confirm            True       NaN       NaN
# 1             555  total_duration_minutes             NaN       NaN  2.633333
# 2             555         step_1_duration             NaN       NaN       NaN
# 3             555         step_2_duration             NaN       NaN       NaN
# 4             555               went_back             NaN     False       NaN
# ...           ...                     ...             ...       ...       ...
# 285712    9999729               went_back             NaN      True       NaN
# 285713    9999729         reached_confirm            True       NaN       NaN
# 285714    9999832         reached_confirm           False       NaN       NaN
# 285715    9999832          start_duration             NaN       NaN       NaN
# 285716    9999832               went_back             NaN     False       NaN
#
#               SD        S1    S2   S3   BS  ... clnt_tenure_yr  \
# 0            NaN       NaN   NaN  NaN  NaN  ...            3.0
# 1            NaN       NaN   NaN  NaN  NaN  ...            3.0
# 2            NaN  0.533333   NaN  NaN  NaN  ...            3.0
# 3            NaN       NaN  1.65  NaN  NaN  ...            3.0
# 4            NaN       NaN   NaN  NaN  NaN  ...            3.0
# ...          ...       ...   ...  ...  ...  ...            ...
# 285712       NaN       NaN   NaN  NaN  NaN  ...           10.0
# 285713       NaN       NaN   NaN  NaN  NaN  ...           10.0
# 285714       NaN       NaN   NaN  NaN  NaN  ...           23.0
# 285715  0.133333       NaN   NaN  NaN  NaN  ...           23.0
# 285716       NaN       NaN   NaN  NaN  NaN  ...           23.0
#
#        clnt_tenure_mnth clnt_age  gendr  num_accts        bal calls_6_mnth  \
# 0                  46.0     29.5      U        2.0   25454.66          2.0
# 1                  46.0     29.5      U        2.0   25454.66          2.0
# 2                  46.0     29.5      U        2.0   25454.66          2.0
# 3                  46.0     29.5      U        2.0   25454.66          2.0
# 4                  46.0     29.5      U        2.0   25454.66          2.0
# ...                 ...      ...    ...        ...        ...          ...
# 285712            124.0     31.0      F        3.0  107059.74          6.0
# 285713            124.0     31.0      F        3.0  107059.74          6.0
# 285714            281.0     49.0      F        2.0  431887.61          1.0
# 285715            281.0     49.0      F        2.0  431887.61          1.0
# 285716            281.0     49.0      F        2.0  431887.61          1.0
#
#         logons_6_mnth  clnt_age_rounded  age_category
# 0                 6.0              30.0         20-30
# 1                 6.0              30.0         20-30
# 2                 6.0              30.0         20-30
# 3                 6.0              30.0         20-30
# 4                 6.0              30.0         20-30
# ...               ...               ...           ...
# 285712            9.0              31.0         30-40
# 285713            9.0              31.0         30-40
# 285714            4.0              49.0         40-50
# 285715            4.0              49.0         40-50
# 285716            4.0              49.0         40-50
#
# [285717 rows x 23 columns]

# %%
plt.figure(figsize=(10, 6))  # Optional: Set the figure size for better clarity
sns.histplot(control_all_BS2['time'], bins=50, kde=False, edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
control_step_1_duration['time'].mean()

# %%
control_grouped_mean = control.groupby('level_1')['time'].mean().reset_index()
control_grouped_mean

# %%
control_all[control_all['variation'] == 'Control'].count
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'variation'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[192], line 1
# ----> 1 control_all[control_all['variation'] == 'Control'].count
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'variation'
